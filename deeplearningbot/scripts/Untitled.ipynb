# %%
import os
import cv2

# %%
i=0
for filename in os.listdir("/Deep Learning Bot/home/nvidia/data/images"):
    image = cv2.imread("/Deep Learning Bot/home/nvidia/data/images/"+str(filename))
    flipped_image = cv2.flip(image,1)
    i=i+1
    #print(filename)
    #print(str(int(filename.split(".")[0]) + 15200).zfill(8) +str(".jpg"))
    #print(i)
    cv2.imwrite(str("/Deep Learning Bot/home/nvidia/data/new_data/images/") + str(int(filename.split(".")[0]) + 15200).zfill(8) +str(".jpg") ,flipped_image)
    
for filename in os.listdir("/Deep Learning Bot/home/nvidia/data/cmd_vel"):
    file1 = open("/Deep Learning Bot/home/nvidia/data/cmd_vel/"+str(filename))
    print(filename.split(".")[0])
    list_str = file1.read().split("	")
    #print(list_str[0])
    #print(float((list_str[1]))*-1)
    file2 = open("/Deep Learning Bot/home/nvidia/data/new_data/cmd_vel/"+str(int(filename.split(".")[0]) + 15200).zfill(8) + str(".txt"),"w+")
    file2.write(str(list_str[0]) + "	"+ str(float((list_str[1]))*-1))
print(i)
# Out:
# 00009042
# 00006371
# 00000700
# 00010513
# 00004566
# 00014775
# 00003209
# 00002117
# 00005678
# 00012304
# 00012462
# 00002671
# 00014013
# 00004200
# 00010275
# 00007709
# 00000066
# 00001378
# 00009724
# 00006417
# 00010261
# 00000072
# 00009730
# 00006403
# 00012476
# 00002665
# 00014007
# 00004214
# 00013768
# 00004572
# 00014761
# 00002103
# 00012310
# 00009056
# 00011619
# 00006365
# 00000714
# 00010507
# 00008348
# 00013026
# 00003235
# 00014749
# 00012338
# 00005644
# 00014991
# 00011631
# 00001422
# 00007053
# 00008360
# 00007735
# 00008406
# 00010249
# 00001344
# 00011157
# 00009718
# 00005122
# 00013998
# 00003553
# 00013740
# 00002895
# 00005136
# 00002659
# 00003547
# 00002881
# 00013754
# 00004228
# 00007721
# 00008412
# 00001350
# 00011143
# 00006359
# 00011625
# 00001436
# 00000728
# 00007047
# 00008374
# 00013032
# 00003221
# 00005888
# 00014985
# 00005650
# 00005863
# 00011816
# 00009081
# 00007912
# 00013967
# 00013973
# 00007906
# 00011802
# 00009095
# ...
